# %%
import os
import numpy as np
import torch
import glob
import torch.nn as nn
from torchvision.transforms import transforms
from torch.utils.data import DataLoader
from torch.optim import Adam
from torch.autograd import Variable
import torchvision
import pathlib
import matplotlib.pyplot as plt
from torchvision.models import resnet34

# %%
#Checking for devoce
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
#Path for train, valid, test directory
train_path = 'content/train'
valid_path = 'content/valid'
test_path = 'content/test'

# %%
#Transforms
transformer = transforms.Compose([
    transforms.Resize((256, 256)),            # Resize image to 256x256
    transforms.RandomHorizontalFlip(),         # Random horizontal flip
    transforms.RandomVerticalFlip(),           # Random vertical flip (optional, use if needed)
    transforms.RandomRotation(10),             # Random rotation between -10 and 10 degrees
    transforms.ColorJitter(brightness=0.2,     # Randomly change brightness
                           contrast=0.2,       # Randomly change contrast
                           saturation=0.2,     # Randomly change saturation
                           hue=0.1),           # Randomly change hue
    transforms.ToTensor(),                     # Convert image to tensor
    transforms.Normalize(mean=[0.5, 0.5, 0.5],  # Normalize with mean and std
                         std=[0.5, 0.5, 0.5])
])

# %%
#DataLoader
train_loader = DataLoader(
    torchvision.datasets.ImageFolder(train_path,transform=transformer),
    batch_size=128, shuffle=True
)

valid_loader = DataLoader(
    torchvision.datasets.ImageFolder(valid_path,transform=transformer),
    batch_size=128, shuffle=True
)

# %%
#categories
root = pathlib.Path(train_path)
classes = sorted([j.name.split('/')[-1] for j in root.iterdir()])
print(classes)
# Out:
# ['A', 'AA', 'AAA', 'B', 'Black', 'Borer Damaged', 'Elephant Ear', 'Fade', 'Half', 'Incomplete', 'Peaberry', 'Triangle']

# %%
model = resnet34(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, 12)
model = model.to(device)
# Out:
# d:\Experiment\.venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# d:\Experiment\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
#Optimizer and loss function
optimizer = Adam(model.parameters(), lr=0.001, weight_decay=0.0001)
loss_function = nn.CrossEntropyLoss()
num_epochs = 200

# %%
#Calculateing the size of trining and valid images
train_count = len(glob.glob(train_path+'/**/*.jpg'))
valid_count = len(glob.glob(valid_path+'/**/*.jpg'))

# %%
print(train_count,valid_count)
# Out:
# 5760 720

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchvision import datasets, transforms
from torchvision.models import resnet34

# Initialization
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
best_accuracy = 0.0

# Load your dataset
# train_loader and test_loader should be defined before

# Define the model
model = resnet34(num_classes=12)  # Replace 12 with the number of your classes
model.fc = nn.Linear(model.fc.in_features, 12)  # Replace 12 with the number of your classes
model.to(device)

# Define loss function and optimizer
loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_count = len(train_loader.dataset)
valid_count = len(valid_loader.dataset)

for epoch in range(num_epochs):

    # Training phase
    model.train()
    train_accuracy = 0.0
    train_loss = 0.0

    for i, (images, labels) in enumerate(valid_loader):
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * images.size(0)
        _, prediction = torch.max(outputs.data, 1)
        train_accuracy += int(torch.sum(prediction == labels.data))

    train_accuracy = train_accuracy / train_count
    train_loss = train_loss / train_count

    # Evaluation phase
    model.eval()
    valid_accuracy = 0.0
    valid_loss = 0.0

    with torch.no_grad():
        for i, (images, labels) in enumerate(valid_loader):
            images = images.to(device)
            labels = labels.to(device)

            outputs = model(images)
            loss = loss_function(outputs, labels)
            valid_loss += loss.item() * images.size(0)
            _, prediction = torch.max(outputs.data, 1)
            valid_accuracy += int(torch.sum(prediction == labels.data))

    valid_accuracy = valid_accuracy / valid_count
    valid_loss = valid_loss / valid_count

    print(f'Epoch: {epoch} Train Loss: {train_loss:.4f} Train Accuracy: {train_accuracy:.4f} Valid Loss: {valid_loss:.4f} Valid Accuracy: {valid_accuracy:.4f}')

    # Save the best model
    if valid_accuracy > best_accuracy:
        torch.save(model.state_dict(), 'content/resnet34')
        best_accuracy = valid_accuracy
        print("--------------")
        print(best_accuracy)
# Out:
# Epoch: 0 Train Loss: 0.3488 Train Accuracy: 0.0109 Valid Loss: 30.9234 Valid Accuracy: 0.0750
# --------------
# 0.075
# Epoch: 1 Train Loss: 0.3085 Train Accuracy: 0.0130 Valid Loss: 5.5081 Valid Accuracy: 0.0889
# --------------
# 0.08888888888888889
# Epoch: 2 Train Loss: 0.2938 Train Accuracy: 0.0200 Valid Loss: 3.6822 Valid Accuracy: 0.1389
# --------------
# 0.1388888888888889
# Epoch: 3 Train Loss: 0.2802 Train Accuracy: 0.0215 Valid Loss: 3.5833 Valid Accuracy: 0.1458
# --------------
# 0.14583333333333334
# Epoch: 4 Train Loss: 0.2730 Train Accuracy: 0.0260 Valid Loss: 2.7998 Valid Accuracy: 0.1806
# --------------
# 0.18055555555555555
# Epoch: 5 Train Loss: 0.2469 Train Accuracy: 0.0293 Valid Loss: 8.2477 Valid Accuracy: 0.0514
# Epoch: 6 Train Loss: 0.2375 Train Accuracy: 0.0337 Valid Loss: 6.3069 Valid Accuracy: 0.1042
# Epoch: 7 Train Loss: 0.2315 Train Accuracy: 0.0345 Valid Loss: 2.5347 Valid Accuracy: 0.2125
# --------------
# 0.2125
# Epoch: 8 Train Loss: 0.2294 Train Accuracy: 0.0408 Valid Loss: 2.4744 Valid Accuracy: 0.2125
# Epoch: 9 Train Loss: 0.2256 Train Accuracy: 0.0396 Valid Loss: 3.1307 Valid Accuracy: 0.1278
# Epoch: 10 Train Loss: 0.2289 Train Accuracy: 0.0385 Valid Loss: 17.1744 Valid Accuracy: 0.1417
# Epoch: 11 Train Loss: 0.2395 Train Accuracy: 0.0339 Valid Loss: 8.1839 Valid Accuracy: 0.0986
# Epoch: 12 Train Loss: 0.2319 Train Accuracy: 0.0396 Valid Loss: 2.3751 Valid Accuracy: 0.2250
# --------------
# 0.225
# Epoch: 13 Train Loss: 0.2223 Train Accuracy: 0.0418 Valid Loss: 1.8450 Valid Accuracy: 0.3306
# --------------
# 0.33055555555555555
# Epoch: 14 Train Loss: 0.2083 Train Accuracy: 0.0444 Valid Loss: 2.0568 Valid Accuracy: 0.2861
# Epoch: 15 Train Loss: 0.2109 Train Accuracy: 0.0448 Valid Loss: 2.6334 Valid Accuracy: 0.1944
# Epoch: 16 Train Loss: 0.2012 Train Accuracy: 0.0491 Valid Loss: 2.9232 Valid Accuracy: 0.2194
# Epoch: 17 Train Loss: 0.2035 Train Accuracy: 0.0505 Valid Loss: 2.9602 Valid Accuracy: 0.1972
# Epoch: 18 Train Loss: 0.1970 Train Accuracy: 0.0510 Valid Loss: 1.6469 Valid Accuracy: 0.3819
# --------------
# 0.3819444444444444
# Epoch: 19 Train Loss: 0.2057 Train Accuracy: 0.0483 Valid Loss: 3.0935 Valid Accuracy: 0.1903
# Epoch: 20 Train Loss: 0.1970 Train Accuracy: 0.0531 Valid Loss: 3.0497 Valid Accuracy: 0.1903
# Epoch: 21 Train Loss: 0.1827 Train Accuracy: 0.0590 Valid Loss: 4.0466 Valid Accuracy: 0.2000
# Epoch: 22 Train Loss: 0.1766 Train Accuracy: 0.0623 Valid Loss: 3.7027 Valid Accuracy: 0.2014
# Epoch: 23 Train Loss: 0.1793 Train Accuracy: 0.0571 Valid Loss: 5.4843 Valid Accuracy: 0.1875
# Epoch: 24 Train Loss: 0.1664 Train Accuracy: 0.0648 Valid Loss: 8.0073 Valid Accuracy: 0.1625
# Epoch: 25 Train Loss: 0.1675 Train Accuracy: 0.0653 Valid Loss: 1.9434 Valid Accuracy: 0.3236
# Epoch: 26 Train Loss: 0.1693 Train Accuracy: 0.0649 Valid Loss: 4.5112 Valid Accuracy: 0.2222
# Epoch: 27 Train Loss: 0.1693 Train Accuracy: 0.0646 Valid Loss: 5.9492 Valid Accuracy: 0.1750
# Epoch: 28 Train Loss: 0.1614 Train Accuracy: 0.0698 Valid Loss: 1.6181 Valid Accuracy: 0.4181
# --------------
# 0.41805555555555557
# Epoch: 29 Train Loss: 0.1614 Train Accuracy: 0.0655 Valid Loss: 3.6193 Valid Accuracy: 0.2889
# Epoch: 30 Train Loss: 0.1556 Train Accuracy: 0.0701 Valid Loss: 4.6059 Valid Accuracy: 0.2611
# Epoch: 31 Train Loss: 0.1541 Train Accuracy: 0.0708 Valid Loss: 5.1729 Valid Accuracy: 0.1667
# Epoch: 32 Train Loss: 0.1559 Train Accuracy: 0.0703 Valid Loss: 2.8014 Valid Accuracy: 0.3486
# Epoch: 33 Train Loss: 0.1554 Train Accuracy: 0.0686 Valid Loss: 2.5730 Valid Accuracy: 0.3153
# Epoch: 34 Train Loss: 0.1490 Train Accuracy: 0.0715 Valid Loss: 2.2108 Valid Accuracy: 0.3653
# Epoch: 35 Train Loss: 0.1474 Train Accuracy: 0.0722 Valid Loss: 2.3913 Valid Accuracy: 0.2833
# Epoch: 36 Train Loss: 0.1527 Train Accuracy: 0.0693 Valid Loss: 4.0851 Valid Accuracy: 0.2958
# Epoch: 37 Train Loss: 0.1535 Train Accuracy: 0.0689 Valid Loss: 10.7768 Valid Accuracy: 0.1750
# Epoch: 38 Train Loss: 0.1523 Train Accuracy: 0.0712 Valid Loss: 2.8955 Valid Accuracy: 0.3056
# Epoch: 39 Train Loss: 0.1461 Train Accuracy: 0.0719 Valid Loss: 3.7024 Valid Accuracy: 0.2764
# Epoch: 40 Train Loss: 0.1463 Train Accuracy: 0.0731 Valid Loss: 2.2069 Valid Accuracy: 0.3681
# Epoch: 41 Train Loss: 0.1433 Train Accuracy: 0.0727 Valid Loss: 3.3436 Valid Accuracy: 0.3083
# Epoch: 42 Train Loss: 0.1457 Train Accuracy: 0.0745 Valid Loss: 1.7066 Valid Accuracy: 0.4458
# --------------
# 0.44583333333333336
# Epoch: 43 Train Loss: 0.1455 Train Accuracy: 0.0724 Valid Loss: 3.6967 Valid Accuracy: 0.3250
# Epoch: 44 Train Loss: 0.1396 Train Accuracy: 0.0760 Valid Loss: 2.9486 Valid Accuracy: 0.3236
# Epoch: 45 Train Loss: 0.1477 Train Accuracy: 0.0740 Valid Loss: 3.1058 Valid Accuracy: 0.2972
# Epoch: 46 Train Loss: 0.1397 Train Accuracy: 0.0760 Valid Loss: 2.8757 Valid Accuracy: 0.3403
# Epoch: 47 Train Loss: 0.1391 Train Accuracy: 0.0762 Valid Loss: 1.6423 Valid Accuracy: 0.4764
# --------------
# 0.47638888888888886
# Epoch: 48 Train Loss: 0.1414 Train Accuracy: 0.0762 Valid Loss: 2.3751 Valid Accuracy: 0.3361
# Epoch: 49 Train Loss: 0.1381 Train Accuracy: 0.0755 Valid Loss: 9.5011 Valid Accuracy: 0.1722
# Epoch: 50 Train Loss: 0.1388 Train Accuracy: 0.0771 Valid Loss: 3.7249 Valid Accuracy: 0.2556
# Epoch: 51 Train Loss: 0.1316 Train Accuracy: 0.0771 Valid Loss: 1.4767 Valid Accuracy: 0.5069
# --------------
# 0.5069444444444444
# Epoch: 52 Train Loss: 0.1297 Train Accuracy: 0.0797 Valid Loss: 2.1431 Valid Accuracy: 0.4208
# Epoch: 53 Train Loss: 0.1414 Train Accuracy: 0.0743 Valid Loss: 2.3177 Valid Accuracy: 0.3875
# Epoch: 54 Train Loss: 0.1424 Train Accuracy: 0.0750 Valid Loss: 2.4394 Valid Accuracy: 0.3639
# Epoch: 55 Train Loss: 0.1360 Train Accuracy: 0.0762 Valid Loss: 7.3732 Valid Accuracy: 0.1500
# Epoch: 56 Train Loss: 0.1324 Train Accuracy: 0.0788 Valid Loss: 5.6780 Valid Accuracy: 0.2417
# Epoch: 57 Train Loss: 0.1302 Train Accuracy: 0.0793 Valid Loss: 2.0881 Valid Accuracy: 0.3583
# Epoch: 58 Train Loss: 0.1303 Train Accuracy: 0.0773 Valid Loss: 2.0074 Valid Accuracy: 0.3944
# Epoch: 59 Train Loss: 0.1271 Train Accuracy: 0.0813 Valid Loss: 1.9476 Valid Accuracy: 0.3875
# Epoch: 60 Train Loss: 0.1294 Train Accuracy: 0.0778 Valid Loss: 2.7241 Valid Accuracy: 0.2847
# Epoch: 61 Train Loss: 0.1255 Train Accuracy: 0.0788 Valid Loss: 1.7742 Valid Accuracy: 0.4500
# Epoch: 62 Train Loss: 0.1309 Train Accuracy: 0.0773 Valid Loss: 2.1535 Valid Accuracy: 0.3694
# Epoch: 63 Train Loss: 0.1386 Train Accuracy: 0.0731 Valid Loss: 1.4500 Valid Accuracy: 0.5472
# --------------
# 0.5472222222222223
# Epoch: 64 Train Loss: 0.1251 Train Accuracy: 0.0785 Valid Loss: 1.4694 Valid Accuracy: 0.5014
# Epoch: 65 Train Loss: 0.1301 Train Accuracy: 0.0773 Valid Loss: 2.0056 Valid Accuracy: 0.4097
# Epoch: 66 Train Loss: 0.1274 Train Accuracy: 0.0816 Valid Loss: 2.8117 Valid Accuracy: 0.2958
# Epoch: 67 Train Loss: 0.1293 Train Accuracy: 0.0802 Valid Loss: 1.3734 Valid Accuracy: 0.5028
# Epoch: 68 Train Loss: 0.1213 Train Accuracy: 0.0802 Valid Loss: 1.2406 Valid Accuracy: 0.5639
# --------------
# 0.5638888888888889
# Epoch: 69 Train Loss: 0.1152 Train Accuracy: 0.0865 Valid Loss: 2.2088 Valid Accuracy: 0.4236
# Epoch: 70 Train Loss: 0.1167 Train Accuracy: 0.0830 Valid Loss: 4.7876 Valid Accuracy: 0.4083
# Epoch: 71 Train Loss: 0.1204 Train Accuracy: 0.0818 Valid Loss: 1.7038 Valid Accuracy: 0.4583
# Epoch: 72 Train Loss: 0.1160 Train Accuracy: 0.0828 Valid Loss: 3.5778 Valid Accuracy: 0.2903
# Epoch: 73 Train Loss: 0.1212 Train Accuracy: 0.0792 Valid Loss: 5.6371 Valid Accuracy: 0.2111
# Epoch: 74 Train Loss: 0.1197 Train Accuracy: 0.0818 Valid Loss: 2.5927 Valid Accuracy: 0.3444
# Epoch: 75 Train Loss: 0.1153 Train Accuracy: 0.0833 Valid Loss: 2.4142 Valid Accuracy: 0.3958
# Epoch: 76 Train Loss: 0.1146 Train Accuracy: 0.0821 Valid Loss: 2.0204 Valid Accuracy: 0.4153
# Epoch: 77 Train Loss: 0.1149 Train Accuracy: 0.0845 Valid Loss: 1.4272 Valid Accuracy: 0.5347
# Epoch: 78 Train Loss: 0.1158 Train Accuracy: 0.0840 Valid Loss: 1.1957 Valid Accuracy: 0.5917
# --------------
# 0.5916666666666667
# Epoch: 79 Train Loss: 0.1164 Train Accuracy: 0.0866 Valid Loss: 1.6837 Valid Accuracy: 0.4583
# Epoch: 80 Train Loss: 0.1111 Train Accuracy: 0.0845 Valid Loss: 1.8521 Valid Accuracy: 0.4236
# Epoch: 81 Train Loss: 0.1075 Train Accuracy: 0.0875 Valid Loss: 1.9476 Valid Accuracy: 0.4097
# Epoch: 82 Train Loss: 0.1072 Train Accuracy: 0.0889 Valid Loss: 3.0314 Valid Accuracy: 0.3792
# Epoch: 83 Train Loss: 0.1177 Train Accuracy: 0.0830 Valid Loss: 0.9943 Valid Accuracy: 0.6486
# --------------
# 0.6486111111111111
# Epoch: 84 Train Loss: 0.1091 Train Accuracy: 0.0833 Valid Loss: 1.2907 Valid Accuracy: 0.5306
# Epoch: 85 Train Loss: 0.1086 Train Accuracy: 0.0861 Valid Loss: 1.3289 Valid Accuracy: 0.5708
# Epoch: 86 Train Loss: 0.1104 Train Accuracy: 0.0851 Valid Loss: 1.7127 Valid Accuracy: 0.4528
# Epoch: 87 Train Loss: 0.0969 Train Accuracy: 0.0901 Valid Loss: 1.1558 Valid Accuracy: 0.5861
# Epoch: 88 Train Loss: 0.1063 Train Accuracy: 0.0877 Valid Loss: 2.0046 Valid Accuracy: 0.4194
# Epoch: 89 Train Loss: 0.1009 Train Accuracy: 0.0894 Valid Loss: 0.8763 Valid Accuracy: 0.6958
# --------------
# 0.6958333333333333
# Epoch: 90 Train Loss: 0.1010 Train Accuracy: 0.0906 Valid Loss: 1.9986 Valid Accuracy: 0.5014
# Epoch: 91 Train Loss: 0.1045 Train Accuracy: 0.0877 Valid Loss: 2.4091 Valid Accuracy: 0.3875
# Epoch: 92 Train Loss: 0.1027 Train Accuracy: 0.0887 Valid Loss: 2.1118 Valid Accuracy: 0.3875
# Epoch: 93 Train Loss: 0.0987 Train Accuracy: 0.0929 Valid Loss: 1.5333 Valid Accuracy: 0.5194
# Epoch: 94 Train Loss: 0.1033 Train Accuracy: 0.0863 Valid Loss: 1.6702 Valid Accuracy: 0.5000
# Epoch: 95 Train Loss: 0.0956 Train Accuracy: 0.0917 Valid Loss: 1.3236 Valid Accuracy: 0.5417
# Epoch: 96 Train Loss: 0.1002 Train Accuracy: 0.0882 Valid Loss: 1.1739 Valid Accuracy: 0.5972
# Epoch: 97 Train Loss: 0.0931 Train Accuracy: 0.0932 Valid Loss: 1.5274 Valid Accuracy: 0.5181
# Epoch: 98 Train Loss: 0.0890 Train Accuracy: 0.0946 Valid Loss: 1.2345 Valid Accuracy: 0.6236
# Epoch: 99 Train Loss: 0.0847 Train Accuracy: 0.0939 Valid Loss: 1.8793 Valid Accuracy: 0.4208
# Epoch: 100 Train Loss: 0.0835 Train Accuracy: 0.0957 Valid Loss: 0.9632 Valid Accuracy: 0.6361
# Epoch: 101 Train Loss: 0.0851 Train Accuracy: 0.0948 Valid Loss: 2.6800 Valid Accuracy: 0.3889
# Epoch: 102 Train Loss: 0.0916 Train Accuracy: 0.0924 Valid Loss: 2.5510 Valid Accuracy: 0.4347
# Epoch: 103 Train Loss: 0.0868 Train Accuracy: 0.0936 Valid Loss: 3.0060 Valid Accuracy: 0.3208
# Epoch: 104 Train Loss: 0.0800 Train Accuracy: 0.0965 Valid Loss: 2.7289 Valid Accuracy: 0.3736
# Epoch: 105 Train Loss: 0.0808 Train Accuracy: 0.0974 Valid Loss: 3.1211 Valid Accuracy: 0.4111
# Epoch: 106 Train Loss: 0.0865 Train Accuracy: 0.0948 Valid Loss: 3.9774 Valid Accuracy: 0.3417
# Epoch: 107 Train Loss: 0.0808 Train Accuracy: 0.0965 Valid Loss: 1.1590 Valid Accuracy: 0.6319
# Epoch: 108 Train Loss: 0.0822 Train Accuracy: 0.0965 Valid Loss: 0.9365 Valid Accuracy: 0.6792
# Epoch: 109 Train Loss: 0.0747 Train Accuracy: 0.0991 Valid Loss: 1.5950 Valid Accuracy: 0.5028
# Epoch: 110 Train Loss: 0.0736 Train Accuracy: 0.1002 Valid Loss: 2.5972 Valid Accuracy: 0.3806
# Epoch: 111 Train Loss: 0.0792 Train Accuracy: 0.0993 Valid Loss: 1.0827 Valid Accuracy: 0.6514
# Epoch: 112 Train Loss: 0.0751 Train Accuracy: 0.1000 Valid Loss: 1.2081 Valid Accuracy: 0.6486
# Epoch: 113 Train Loss: 0.0738 Train Accuracy: 0.0990 Valid Loss: 2.7607 Valid Accuracy: 0.4694
# Epoch: 114 Train Loss: 0.0693 Train Accuracy: 0.1002 Valid Loss: 2.0065 Valid Accuracy: 0.4722
# Epoch: 115 Train Loss: 0.0741 Train Accuracy: 0.0984 Valid Loss: 0.9211 Valid Accuracy: 0.6708
# Epoch: 116 Train Loss: 0.0692 Train Accuracy: 0.1021 Valid Loss: 2.5929 Valid Accuracy: 0.3736
# Epoch: 117 Train Loss: 0.0774 Train Accuracy: 0.0977 Valid Loss: 1.5152 Valid Accuracy: 0.5500
# Epoch: 118 Train Loss: 0.0700 Train Accuracy: 0.1009 Valid Loss: 1.1955 Valid Accuracy: 0.5972
# Epoch: 119 Train Loss: 0.0738 Train Accuracy: 0.0986 Valid Loss: 0.6832 Valid Accuracy: 0.7569
# --------------
# 0.7569444444444444
# Epoch: 120 Train Loss: 0.0740 Train Accuracy: 0.0995 Valid Loss: 2.6018 Valid Accuracy: 0.4556
# Epoch: 121 Train Loss: 0.0693 Train Accuracy: 0.1010 Valid Loss: 1.2457 Valid Accuracy: 0.6014
# Epoch: 122 Train Loss: 0.0628 Train Accuracy: 0.1047 Valid Loss: 0.6645 Valid Accuracy: 0.7458
# Epoch: 123 Train Loss: 0.0691 Train Accuracy: 0.1009 Valid Loss: 0.8652 Valid Accuracy: 0.7125
# Epoch: 124 Train Loss: 0.0687 Train Accuracy: 0.1019 Valid Loss: 1.0403 Valid Accuracy: 0.6528
# Epoch: 125 Train Loss: 0.0589 Train Accuracy: 0.1057 Valid Loss: 1.7712 Valid Accuracy: 0.5694
# Epoch: 126 Train Loss: 0.0661 Train Accuracy: 0.1030 Valid Loss: 0.9559 Valid Accuracy: 0.6764
# Epoch: 127 Train Loss: 0.0655 Train Accuracy: 0.1026 Valid Loss: 1.0167 Valid Accuracy: 0.6653
# Epoch: 128 Train Loss: 0.0630 Train Accuracy: 0.1012 Valid Loss: 5.5541 Valid Accuracy: 0.3681
# Epoch: 129 Train Loss: 0.0652 Train Accuracy: 0.1030 Valid Loss: 0.8266 Valid Accuracy: 0.7306
# Epoch: 130 Train Loss: 0.0544 Train Accuracy: 0.1064 Valid Loss: 1.6205 Valid Accuracy: 0.5139
# Epoch: 131 Train Loss: 0.0605 Train Accuracy: 0.1033 Valid Loss: 1.2134 Valid Accuracy: 0.6278
# Epoch: 132 Train Loss: 0.0600 Train Accuracy: 0.1052 Valid Loss: 1.4119 Valid Accuracy: 0.5236
# Epoch: 133 Train Loss: 0.0592 Train Accuracy: 0.1045 Valid Loss: 0.5895 Valid Accuracy: 0.7861
# --------------
# 0.7861111111111111
# Epoch: 134 Train Loss: 0.0519 Train Accuracy: 0.1071 Valid Loss: 3.1613 Valid Accuracy: 0.3486
# Epoch: 135 Train Loss: 0.0605 Train Accuracy: 0.1024 Valid Loss: 1.0924 Valid Accuracy: 0.6792
# Epoch: 136 Train Loss: 0.0551 Train Accuracy: 0.1064 Valid Loss: 1.1481 Valid Accuracy: 0.6319
# Epoch: 137 Train Loss: 0.0572 Train Accuracy: 0.1054 Valid Loss: 0.6046 Valid Accuracy: 0.7792
# Epoch: 138 Train Loss: 0.0568 Train Accuracy: 0.1026 Valid Loss: 0.5949 Valid Accuracy: 0.7778
# Epoch: 139 Train Loss: 0.0544 Train Accuracy: 0.1059 Valid Loss: 0.7194 Valid Accuracy: 0.7542
# Epoch: 140 Train Loss: 0.0519 Train Accuracy: 0.1082 Valid Loss: 3.3459 Valid Accuracy: 0.4514
# Epoch: 141 Train Loss: 0.0572 Train Accuracy: 0.1056 Valid Loss: 0.5428 Valid Accuracy: 0.8083
# --------------
# 0.8083333333333333
# Epoch: 142 Train Loss: 0.0574 Train Accuracy: 0.1045 Valid Loss: 1.5548 Valid Accuracy: 0.5597
# Epoch: 143 Train Loss: 0.0538 Train Accuracy: 0.1066 Valid Loss: 0.6274 Valid Accuracy: 0.7736
# Epoch: 144 Train Loss: 0.0510 Train Accuracy: 0.1076 Valid Loss: 0.8058 Valid Accuracy: 0.7264
# Epoch: 145 Train Loss: 0.0571 Train Accuracy: 0.1059 Valid Loss: 1.4355 Valid Accuracy: 0.5861
# Epoch: 146 Train Loss: 0.0552 Train Accuracy: 0.1064 Valid Loss: 0.8842 Valid Accuracy: 0.6986
# Epoch: 147 Train Loss: 0.0460 Train Accuracy: 0.1087 Valid Loss: 0.8337 Valid Accuracy: 0.7194
# Epoch: 148 Train Loss: 0.0513 Train Accuracy: 0.1059 Valid Loss: 2.5230 Valid Accuracy: 0.5153
# Epoch: 149 Train Loss: 0.0456 Train Accuracy: 0.1094 Valid Loss: 1.4352 Valid Accuracy: 0.5889
# Epoch: 150 Train Loss: 0.0429 Train Accuracy: 0.1092 Valid Loss: 1.3666 Valid Accuracy: 0.6236
# Epoch: 151 Train Loss: 0.0498 Train Accuracy: 0.1069 Valid Loss: 0.8057 Valid Accuracy: 0.7389
# Epoch: 152 Train Loss: 0.0489 Train Accuracy: 0.1089 Valid Loss: 1.3076 Valid Accuracy: 0.6389
# Epoch: 153 Train Loss: 0.0457 Train Accuracy: 0.1082 Valid Loss: 1.5216 Valid Accuracy: 0.5792
# Epoch: 154 Train Loss: 0.0446 Train Accuracy: 0.1099 Valid Loss: 0.5230 Valid Accuracy: 0.8097
# --------------
# 0.8097222222222222
# Epoch: 155 Train Loss: 0.0363 Train Accuracy: 0.1116 Valid Loss: 0.9799 Valid Accuracy: 0.7153
# Epoch: 156 Train Loss: 0.0440 Train Accuracy: 0.1092 Valid Loss: 0.9738 Valid Accuracy: 0.6736
# Epoch: 157 Train Loss: 0.0421 Train Accuracy: 0.1094 Valid Loss: 1.0406 Valid Accuracy: 0.6931
# Epoch: 158 Train Loss: 0.0372 Train Accuracy: 0.1109 Valid Loss: 1.4231 Valid Accuracy: 0.6792
# Epoch: 159 Train Loss: 0.0438 Train Accuracy: 0.1094 Valid Loss: 0.7877 Valid Accuracy: 0.7139
# Epoch: 160 Train Loss: 0.0413 Train Accuracy: 0.1095 Valid Loss: 1.8905 Valid Accuracy: 0.5000
# Epoch: 161 Train Loss: 0.0350 Train Accuracy: 0.1123 Valid Loss: 0.9214 Valid Accuracy: 0.7250
# Epoch: 162 Train Loss: 0.0384 Train Accuracy: 0.1115 Valid Loss: 0.8420 Valid Accuracy: 0.7181
# Epoch: 163 Train Loss: 0.0360 Train Accuracy: 0.1146 Valid Loss: 0.6285 Valid Accuracy: 0.7833
# Epoch: 164 Train Loss: 0.0400 Train Accuracy: 0.1108 Valid Loss: 1.1681 Valid Accuracy: 0.6583
# Epoch: 165 Train Loss: 0.0366 Train Accuracy: 0.1118 Valid Loss: 0.7344 Valid Accuracy: 0.7778
# Epoch: 166 Train Loss: 0.0362 Train Accuracy: 0.1135 Valid Loss: 0.4675 Valid Accuracy: 0.8292
# --------------
# 0.8291666666666667
# Epoch: 167 Train Loss: 0.0433 Train Accuracy: 0.1108 Valid Loss: 1.1482 Valid Accuracy: 0.6806
# Epoch: 168 Train Loss: 0.0312 Train Accuracy: 0.1144 Valid Loss: 0.4338 Valid Accuracy: 0.8528
# --------------
# 0.8527777777777777
# Epoch: 169 Train Loss: 0.0361 Train Accuracy: 0.1116 Valid Loss: 1.0961 Valid Accuracy: 0.6611
# Epoch: 170 Train Loss: 0.0376 Train Accuracy: 0.1127 Valid Loss: 0.3103 Valid Accuracy: 0.8833
# --------------
# 0.8833333333333333
# Epoch: 171 Train Loss: 0.0387 Train Accuracy: 0.1118 Valid Loss: 0.5936 Valid Accuracy: 0.7944
# Epoch: 172 Train Loss: 0.0342 Train Accuracy: 0.1141 Valid Loss: 0.6338 Valid Accuracy: 0.7750
# Epoch: 173 Train Loss: 0.0340 Train Accuracy: 0.1128 Valid Loss: 0.8733 Valid Accuracy: 0.7500
# Epoch: 174 Train Loss: 0.0425 Train Accuracy: 0.1095 Valid Loss: 1.8654 Valid Accuracy: 0.5194
# Epoch: 175 Train Loss: 0.0417 Train Accuracy: 0.1113 Valid Loss: 0.7522 Valid Accuracy: 0.7500
# Epoch: 176 Train Loss: 0.0428 Train Accuracy: 0.1106 Valid Loss: 1.2120 Valid Accuracy: 0.6792
# Epoch: 177 Train Loss: 0.0378 Train Accuracy: 0.1118 Valid Loss: 2.5446 Valid Accuracy: 0.5208
# Epoch: 178 Train Loss: 0.0418 Train Accuracy: 0.1099 Valid Loss: 1.0966 Valid Accuracy: 0.7181
# Epoch: 179 Train Loss: 0.0352 Train Accuracy: 0.1128 Valid Loss: 0.4936 Valid Accuracy: 0.8347
# Epoch: 180 Train Loss: 0.0329 Train Accuracy: 0.1125 Valid Loss: 0.5000 Valid Accuracy: 0.8250
# Epoch: 181 Train Loss: 0.0313 Train Accuracy: 0.1146 Valid Loss: 0.5513 Valid Accuracy: 0.8181
# Epoch: 182 Train Loss: 0.0299 Train Accuracy: 0.1146 Valid Loss: 0.3308 Valid Accuracy: 0.8708
# Epoch: 183 Train Loss: 0.0282 Train Accuracy: 0.1153 Valid Loss: 0.3517 Valid Accuracy: 0.8861
# --------------
# 0.8861111111111111
# Epoch: 184 Train Loss: 0.0284 Train Accuracy: 0.1151 Valid Loss: 0.4769 Valid Accuracy: 0.8417
# Epoch: 185 Train Loss: 0.0260 Train Accuracy: 0.1174 Valid Loss: 0.3834 Valid Accuracy: 0.8625
# Epoch: 186 Train Loss: 0.0263 Train Accuracy: 0.1155 Valid Loss: 0.7441 Valid Accuracy: 0.7583
# Epoch: 187 Train Loss: 0.0250 Train Accuracy: 0.1151 Valid Loss: 0.3474 Valid Accuracy: 0.8792
# Epoch: 188 Train Loss: 0.0274 Train Accuracy: 0.1137 Valid Loss: 0.6630 Valid Accuracy: 0.7806
# Epoch: 189 Train Loss: 0.0306 Train Accuracy: 0.1148 Valid Loss: 0.6736 Valid Accuracy: 0.7778
# Epoch: 190 Train Loss: 0.0240 Train Accuracy: 0.1170 Valid Loss: 0.5628 Valid Accuracy: 0.8056
# Epoch: 191 Train Loss: 0.0243 Train Accuracy: 0.1167 Valid Loss: 0.3226 Valid Accuracy: 0.8903
# --------------
# 0.8902777777777777
# Epoch: 192 Train Loss: 0.0237 Train Accuracy: 0.1165 Valid Loss: 0.4938 Valid Accuracy: 0.8236
# Epoch: 193 Train Loss: 0.0261 Train Accuracy: 0.1163 Valid Loss: 2.2797 Valid Accuracy: 0.5625
# Epoch: 194 Train Loss: 0.0284 Train Accuracy: 0.1148 Valid Loss: 2.6031 Valid Accuracy: 0.5528
# Epoch: 195 Train Loss: 0.0259 Train Accuracy: 0.1142 Valid Loss: 0.8017 Valid Accuracy: 0.7486
# Epoch: 196 Train Loss: 0.0257 Train Accuracy: 0.1165 Valid Loss: 0.3448 Valid Accuracy: 0.8931
# --------------
# 0.8930555555555556
# Epoch: 197 Train Loss: 0.0269 Train Accuracy: 0.1158 Valid Loss: 1.2106 Valid Accuracy: 0.6597
# Epoch: 198 Train Loss: 0.0271 Train Accuracy: 0.1160 Valid Loss: 0.6136 Valid Accuracy: 0.7903
# Epoch: 199 Train Loss: 0.0283 Train Accuracy: 0.1153 Valid Loss: 0.4785 Valid Accuracy: 0.8375

# %%
PATH = 'content/resnet34.pth'
print("\nSaving the model...")
torch.save(model, PATH)
print('Saved!')
# Out:
# Saving the model...
# Saved!

# %%
torch.cuda.empty_cache()  # ล้างหน่วยความจำ CUDA
